# %% [markdown]
# ### Import Libraries

# %%
import re
import pandas as pd
import string
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.chunk import RegexpParser
from nltk import word_tokenize, pos_tag
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
string.punctuation
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# ### Preprocessing

# %%
# read data

data = pd.read_excel('data/isco.xlsx')
data = data[data["ISCO 08 Code"].apply(lambda x: len(str(x)) > 3)]
data = data[["Title EN", "Definition", "Tasks include"]]
data.head()
# Out:
#                                             Title EN  \
# 3                                        Legislators
# 4                        Senior Government Officials
# 5           Traditional Chiefs and Heads of Villages
# 6  Senior Officials of Special-interest Organizat...
# 8            Managing Directors and Chief Executives
#
#                                           Definition  \
# 3  Legislators determine, formulate, and direct p...
# 4  Senior government officials advise governments...
# 5  Traditional chiefs and heads of villages perfo...
# 6  Senior officials of special-interest organizat...
# 8  Managing directors and chief executives formul...
#
#                                        Tasks include
# 3  Tasks include -\n(a)  presiding over or partic...
# 4  Tasks include -\n(a)  advising national, state...
# 5  Tasks include -\n(a)  allocating the use of co...
# 6  Tasks include -\n(a)  determining and formulat...
# 8  Tasks include -\n(a)  planning, directing and ...

# %%
# add . in the end of title
def add_period(text):
    if pd.notna(text):
        return text + ". "
    else:
        return text

# Apply the function to the 'title' column
data['Definition'] = data['Definition'].apply(add_period)

# merge title and abstract column
data['definition_and_task'] = data['Definition'] + data['Tasks include'].fillna('')

# Print the updated DataFrame
data.head()
# Out:
#                                             Title EN  \
# 3                                        Legislators
# 4                        Senior Government Officials
# 5           Traditional Chiefs and Heads of Villages
# 6  Senior Officials of Special-interest Organizat...
# 8            Managing Directors and Chief Executives
#
#                                           Definition  \
# 3  Legislators determine, formulate, and direct p...
# 4  Senior government officials advise governments...
# 5  Traditional chiefs and heads of villages perfo...
# 6  Senior officials of special-interest organizat...
# 8  Managing directors and chief executives formul...
#
#                                        Tasks include  \
# 3  Tasks include -\n(a)  presiding over or partic...
# 4  Tasks include -\n(a)  advising national, state...
# 5  Tasks include -\n(a)  allocating the use of co...
# 6  Tasks include -\n(a)  determining and formulat...
# 8  Tasks include -\n(a)  planning, directing and ...
#
#                                  definition_and_task
# 3  Legislators determine, formulate, and direct p...
# 4  Senior government officials advise governments...
# 5  Traditional chiefs and heads of villages perfo...
# 6  Senior officials of special-interest organizat...
# 8  Managing directors and chief executives formul...

# %%
# check missing value

print(data.isna().sum())
# Out:
# Title EN               0
# Definition             0
# Tasks include          6
# definition_and_task    0
# dtype: int64

# %%
# # remove missing value (tidak perlu karena kolom title and abstract tidak memiliki missing value)

# data.dropna(inplace=True)
# data.head()
data
# Out:
#                                               Title EN  \
# 3                                          Legislators
# 4                          Senior Government Officials
# 5             Traditional Chiefs and Heads of Villages
# 6    Senior Officials of Special-interest Organizat...
# 8              Managing Directors and Chief Executives
# ..                                                 ...
# 604  Messengers, Package Deliverers and Luggage Por...
# 605                                    Odd Job Persons
# 606       Meter Readers and Vending-machine Collectors
# 607                      Water and Firewood Collectors
# 608        Elementary Workers Not Elsewhere Classified
#
#                                             Definition  \
# 3    Legislators determine, formulate, and direct p...
# 4    Senior government officials advise governments...
# 5    Traditional chiefs and heads of villages perfo...
# 6    Senior officials of special-interest organizat...
# 8    Managing directors and chief executives formul...
# ..                                                 ...
# 604  Messengers, package deliverers and luggage por...
# 605  Odd job persons clean, paint and maintain buil...
# 606  Meter readers and vending-machine collectors s...
# 607  Water and firewood collectors collect water an...
# 608  This unit group covers elementary workers not ...
#
#                                          Tasks include  \
# 3    Tasks include -\n(a)  presiding over or partic...
# 4    Tasks include -\n(a)  advising national, state...
# 5    Tasks include -\n(a)  allocating the use of co...
# 6    Tasks include -\n(a)  determining and formulat...
# 8    Tasks include -\n(a)  planning, directing and ...
# ..                                                 ...
# 604  Tasks include -\n(a)  delivering messages, pac...
# 605  Tasks include -\n(a)  repairing broken windows...
# 606  Tasks include -\n(a)  filling storage areas of...
# 607  Tasks include -\n(a)  cutting and collecting w...
# 608  In such cases tasks would include -\n(a)  sell...
#
#                                    definition_and_task
# 3    Legislators determine, formulate, and direct p...
# 4    Senior government officials advise governments...
# 5    Traditional chiefs and heads of villages perfo...
# 6    Senior officials of special-interest organizat...
# 8    Managing directors and chief executives formul...
# ..                                                 ...
# 604  Messengers, package deliverers and luggage por...
# 605  Odd job persons clean, paint and maintain buil...
# 606  Meter readers and vending-machine collectors s...
# 607  Water and firewood collectors collect water an...
# 608  This unit group covers elementary workers not ...
#
# [433 rows x 4 columns]

# %%
# lowering text
data['lowered']= data['definition_and_task'].apply(lambda x: x.lower())

# Print the updated DataFrame
data['lowered'].head()
# Out:
# 3    legislators determine, formulate, and direct p...
# 4    senior government officials advise governments...
# 5    traditional chiefs and heads of villages perfo...
# 6    senior officials of special-interest organizat...
# 8    managing directors and chief executives formul...
# Name: lowered, dtype: object

# %%
# Function to tokenize each sentence, tokenize each word from sentence, then remove punctuation and sopword
def tokenize_and_remove_punctuation(text):
    # Define stopword
    stop_words = set(stopwords.words('english'))

    # Tokenize each sentence
    sentences = re.split(r'(?<=[.!?,;])\s+', text)
    
    # Tokenize each word in each sentence, remove punctuation, and remove stopword
    tokenized_sentences = []
    for sentence in sentences:
        tokens = word_tokenize(sentence)
        # Remove punctuation
        tokens = [token for token in tokens if token not in string.punctuation]
        # Remove stopword
        tokens = [token for token in tokens if token not in stop_words]
        tokenized_sentences.append(tokens)
    return tokenized_sentences

# Tokenize each sentence and remove punctuation & stopword
data['tokenized'] = data['lowered'].apply(tokenize_and_remove_punctuation)

# Print the updated DataFrame
print(data['tokenized'][3])
# Out:
# [['legislators', 'determine'], ['formulate'], ['direct', 'policies', 'national'], ['state'], ['regional', 'local', 'governments', 'international', 'governmental', 'agencies'], ['make'], ['ratify'], ['amend', 'repeal', 'laws'], ['public', 'rules', 'regulations'], ['include', 'elected', 'non-elected', 'members', 'parliaments'], ['councils', 'governments', '..'], ['tasks', 'include', 'presiding', 'participating', 'proceedings', 'legislative', 'bodies', 'administrative', 'councils', 'national'], ['state'], ['regional', 'local', 'governments', 'legislative', 'assemblies'], ['b', 'determining'], ['formulating', 'directing', 'policies', 'national'], ['state'], ['regional', 'local', 'governments'], ['c', 'making'], ['ratifying'], ['amending', 'repealing', 'laws'], ['public', 'rules', 'regulations', 'within', 'statutory', 'constitutional', 'framework'], ['serving', 'government', 'administrative', 'boards', 'official', 'committees'], ['e', 'investigating', 'matters', 'concern', 'public', 'promoting', 'interests', 'constituencies', 'represent'], ['f', 'attending', 'community', 'functions', 'meetings', 'provide', 'service', 'community'], ['understand', 'public', 'opinion', 'provide', 'information', 'government', 'plans'], ['g', 'negotiating', 'legislators', 'representatives', 'interest', 'groups', 'order', 'reconcile', 'differing', 'interests'], ['create', 'policies', 'agreements'], ['h', 'members', 'government'], ['directing', 'senior', 'administrators', 'officials', 'government', 'departments', 'agencies', 'interpretation', 'implementation', 'government', 'policies']]

# %% [markdown]
# ### POS Tag

# %%
# Function to perform POS tagging on each token
def pos_tag_tokens(tokenized_sentences):
    pos_tagged_sentences = []
    for sentence_tokens in tokenized_sentences:
        pos_tags = pos_tag(sentence_tokens)
        pos_tagged_sentences.append(pos_tags)
    return pos_tagged_sentences

# Perform POS tagging on tokenized sentences
data['pos_tagged'] = data['tokenized'].apply(pos_tag_tokens)

# Print the updated DataFrame
print(data['pos_tagged'][3])
# Out:
# [[('legislators', 'NNS'), ('determine', 'VBP')], [('formulate', 'NN')], [('direct', 'JJ'), ('policies', 'NNS'), ('national', 'JJ')], [('state', 'NN')], [('regional', 'JJ'), ('local', 'JJ'), ('governments', 'NNS'), ('international', 'JJ'), ('governmental', 'JJ'), ('agencies', 'NNS')], [('make', 'VB')], [('ratify', 'VB')], [('amend', 'JJ'), ('repeal', 'NN'), ('laws', 'NNS')], [('public', 'JJ'), ('rules', 'NNS'), ('regulations', 'NNS')], [('include', 'NN'), ('elected', 'VBD'), ('non-elected', 'JJ'), ('members', 'NNS'), ('parliaments', 'NNS')], [('councils', 'NNS'), ('governments', 'NNS'), ('..', 'VBP')], [('tasks', 'NNS'), ('include', 'VBP'), ('presiding', 'VBG'), ('participating', 'VBG'), ('proceedings', 'NNS'), ('legislative', 'JJ'), ('bodies', 'NNS'), ('administrative', 'VBP'), ('councils', 'NNS'), ('national', 'JJ')], [('state', 'NN')], [('regional', 'JJ'), ('local', 'JJ'), ('governments', 'NNS'), ('legislative', 'JJ'), ('assemblies', 'NNS')], [('b', 'NN'), ('determining', 'VBG')], [('formulating', 'VBG'), ('directing', 'VBG'), ('policies', 'NNS'), ('national', 'JJ')], [('state', 'NN')], [('regional', 'JJ'), ('local', 'JJ'), ('governments', 'NNS')], [('c', 'NNS'), ('making', 'VBG')], [('ratifying', 'VBG')], [('amending', 'VBG'), ('repealing', 'VBG'), ('laws', 'NNS')], [('public', 'JJ'), ('rules', 'NNS'), ('regulations', 'NNS'), ('within', 'IN'), ('statutory', 'JJ'), ('constitutional', 'JJ'), ('framework', 'NN')], [('serving', 'VBG'), ('government', 'NN'), ('administrative', 'JJ'), ('boards', 'NNS'), ('official', 'NN'), ('committees', 'NNS')], [('e', 'NN'), ('investigating', 'VBG'), ('matters', 'NNS'), ('concern', 'NN'), ('public', 'JJ'), ('promoting', 'NN'), ('interests', 'NNS'), ('constituencies', 'NNS'), ('represent', 'VBP')], [('f', 'JJ'), ('attending', 'VBG'), ('community', 'NN'), ('functions', 'NNS'), ('meetings', 'NNS'), ('provide', 'VBP'), ('service', 'NN'), ('community', 'NN')], [('understand', 'JJ'), ('public', 'JJ'), ('opinion', 'NN'), ('provide', 'IN'), ('information', 'NN'), ('government', 'NN'), ('plans', 'NNS')], [('g', 'NN'), ('negotiating', 'VBG'), ('legislators', 'NNS'), ('representatives', 'NNS'), ('interest', 'NN'), ('groups', 'NNS'), ('order', 'NN'), ('reconcile', 'NN'), ('differing', 'NN'), ('interests', 'NNS')], [('create', 'NN'), ('policies', 'NNS'), ('agreements', 'NNS')], [('h', 'NN'), ('members', 'NNS'), ('government', 'NN')], [('directing', 'VBG'), ('senior', 'JJ'), ('administrators', 'NNS'), ('officials', 'NNS'), ('government', 'NN'), ('departments', 'NNS'), ('agencies', 'NNS'), ('interpretation', 'VBP'), ('implementation', 'JJ'), ('government', 'NN'), ('policies', 'NNS')]]

# %%
# Function to lemmatize tokens
def lemmatize_tokens(pos_tagged_sentences):
    lemmatizer = WordNetLemmatizer()
    lemmatized_sentences = []
    for sentence_tags in pos_tagged_sentences:
        lemmatized_tokens = [(lemmatizer.lemmatize(token, pos=get_wordnet_pos(pos_tag)), pos_tag) for token, pos_tag in sentence_tags]
        lemmatized_sentences.append(lemmatized_tokens)
    return lemmatized_sentences

# Function to map POS tags to WordNet POS tags
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return nltk.corpus.wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return nltk.corpus.wordnet.VERB
    elif treebank_tag.startswith('N'):
        return nltk.corpus.wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return nltk.corpus.wordnet.ADV
    else:
        return nltk.corpus.wordnet.NOUN  # Default to noun if POS tag not recognized

# Lemmatize the tokens in 'pos_tagged_sentences' column
data['lemmatized'] = data['pos_tagged'].apply(lemmatize_tokens)

# Print the updated DataFrame
print(data['lemmatized'][3])
# Out:
# [[('legislator', 'NNS'), ('determine', 'VBP')], [('formulate', 'NN')], [('direct', 'JJ'), ('policy', 'NNS'), ('national', 'JJ')], [('state', 'NN')], [('regional', 'JJ'), ('local', 'JJ'), ('government', 'NNS'), ('international', 'JJ'), ('governmental', 'JJ'), ('agency', 'NNS')], [('make', 'VB')], [('ratify', 'VB')], [('amend', 'JJ'), ('repeal', 'NN'), ('law', 'NNS')], [('public', 'JJ'), ('rule', 'NNS'), ('regulation', 'NNS')], [('include', 'NN'), ('elect', 'VBD'), ('non-elected', 'JJ'), ('member', 'NNS'), ('parliament', 'NNS')], [('council', 'NNS'), ('government', 'NNS'), ('..', 'VBP')], [('task', 'NNS'), ('include', 'VBP'), ('preside', 'VBG'), ('participate', 'VBG'), ('proceeding', 'NNS'), ('legislative', 'JJ'), ('body', 'NNS'), ('administrative', 'VBP'), ('council', 'NNS'), ('national', 'JJ')], [('state', 'NN')], [('regional', 'JJ'), ('local', 'JJ'), ('government', 'NNS'), ('legislative', 'JJ'), ('assembly', 'NNS')], [('b', 'NN'), ('determine', 'VBG')], [('formulate', 'VBG'), ('direct', 'VBG'), ('policy', 'NNS'), ('national', 'JJ')], [('state', 'NN')], [('regional', 'JJ'), ('local', 'JJ'), ('government', 'NNS')], [('c', 'NNS'), ('make', 'VBG')], [('ratify', 'VBG')], [('amend', 'VBG'), ('repeal', 'VBG'), ('law', 'NNS')], [('public', 'JJ'), ('rule', 'NNS'), ('regulation', 'NNS'), ('within', 'IN'), ('statutory', 'JJ'), ('constitutional', 'JJ'), ('framework', 'NN')], [('serve', 'VBG'), ('government', 'NN'), ('administrative', 'JJ'), ('board', 'NNS'), ('official', 'NN'), ('committee', 'NNS')], [('e', 'NN'), ('investigate', 'VBG'), ('matter', 'NNS'), ('concern', 'NN'), ('public', 'JJ'), ('promoting', 'NN'), ('interest', 'NNS'), ('constituency', 'NNS'), ('represent', 'VBP')], [('f', 'JJ'), ('attend', 'VBG'), ('community', 'NN'), ('function', 'NNS'), ('meeting', 'NNS'), ('provide', 'VBP'), ('service', 'NN'), ('community', 'NN')], [('understand', 'JJ'), ('public', 'JJ'), ('opinion', 'NN'), ('provide', 'IN'), ('information', 'NN'), ('government', 'NN'), ('plan', 'NNS')], [('g', 'NN'), ('negotiate', 'VBG'), ('legislator', 'NNS'), ('representative', 'NNS'), ('interest', 'NN'), ('group', 'NNS'), ('order', 'NN'), ('reconcile', 'NN'), ('differing', 'NN'), ('interest', 'NNS')], [('create', 'NN'), ('policy', 'NNS'), ('agreement', 'NNS')], [('h', 'NN'), ('member', 'NNS'), ('government', 'NN')], [('direct', 'VBG'), ('senior', 'JJ'), ('administrator', 'NNS'), ('official', 'NNS'), ('government', 'NN'), ('department', 'NNS'), ('agency', 'NNS'), ('interpretation', 'VBP'), ('implementation', 'JJ'), ('government', 'NN'), ('policy', 'NNS')]]

# %% [markdown]
# ### POS Chunk

# %%
# POS chunk new pattern (Pak Indra)

# define pattern
pattern_raharjana = r'''Chunk: {<VB\w*>+<.|IN|CC|PRP\w*>*<DT>*<NN\w*|RB>+}'''
pattern_webb = r'''Chunk: {<VB\w*><NN\w*>}'''
pattern_johann = r'''Chunk: {<VB\w*><NN\w*>|<VB\w*><PRP\w*><NN\w*>|<VB\w*><NN\w*><NN\w*>|<VB\w*><JJ\w*><NN\w*>|<VB\w*><DT><NN\w*>|<VB\w*><NN\w*><IN><NN\w*>|<VB\w*><IN><JJ\w*><NN\w*>|<VB\w*><PRP\w*><JJ\w*><NN\w*>}'''

def extract(tagged_texts, pattern):
    chunk_parser = RegexpParser(pattern)
    chunks = []
    for tagged_text in tagged_texts:
        tree = chunk_parser.parse(tagged_text)
        tree = extract_chunks(tree)
        tree = trees_to_tuples(tree)
        chunks.append(tree)
    chunks = [item for sublist in chunks for item in sublist]
    return chunks

def extract_chunks(tree):
    chunks = []
    
    if isinstance(tree, nltk.Tree):
        if tree.label() != 'S':  # Exclude sentence-level chunks if any
            chunks.append(tree)
        for subtree in tree:
            chunks.extend(extract_chunks(subtree))
    
    return chunks

def trees_to_tuples(tree_list):
    tuple_list = [tuple(leaf[0] for leaf in tree.leaves()) for tree in tree_list]
    return tuple_list

# Apply chunking and extraction to the 'tagged_sentences' column
data['pattern_webb'] = data['lemmatized'].apply(lambda x: extract(x, pattern_webb))
data['pattern_raharjana'] = data['lemmatized'].apply(lambda x: extract(x, pattern_raharjana))
data['pattern_johann'] = data['lemmatized'].apply(lambda x: extract(x, pattern_johann))

# Print the resulting DataFrame with chunked data
data['pattern_webb']
# Out:
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# 3      [(participate, proceeding), (administrative, c...
# 4      [(advise, government), (establish, government)...
# 5      [(perform, variety), (village, chief), (alloca...
# 6      [(special-interest, organization), (formulate,...
# 8      [(manage, director), (formulate, review), (ent...
#                              ...
# 604    [(luggage, porter), (carry, deliver), (deliver...
# 605    [(light, bulb), (adjust, door), (replace, tap)...
# 606    [(vend, machine), (park, meter), (fill, storag...
# 607    [(collect, water), (use, hand), (collect, wood...
# 608    [(include, issue), (park, admission), (pass, p...
# Name: pattern_webb, Length: 433, dtype: object

# %% [markdown]
# ### Export Result

# %%
# hasile

patent_task = data[["Title EN", "definition_and_task", "pattern_webb", "pattern_raharjana", "pattern_johann"]]
patent_task.to_excel('export_result/isco_3pattern.xlsx', index=False)
